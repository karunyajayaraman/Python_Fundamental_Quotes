# %% [markdown]
# <a href="https://colab.research.google.com/github/karunyajayaraman/Python_Fundamental_Quotes/blob/main/Email_Username_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study – Email Username Generator
# # Instructions:
# # • Create variables: full_name, domain_name
# # • Take input from the user using input() function
# # • Convert full_name into lowercase using lower()
# # • Remove spaces in name and replace with dot using replace()
# # • Split full_name using split() function
# # • Join name parts using join() function if needed
# # • Create email in format: name@domain
# # • Display only Full Name and Generated Email
# # • Use print() and f-string for output display
# # """

# %%
# Create variables: full_name, domain_name

full_name = "Karunya Jayaraman"
domain_name = "gmail.com"

#Take input from the user using input() function

full_name = input("Enter Full_name : ")
domain_name= input("Enter Domain_name : ")

#Convert full_name into lowercase using lower()

full_name = full_name.lower()
print(full_name.lower())

#Remove spaces in name and replace with dot using replace()

full_name = "Karunya Jayaraman"
new_email_name = full_name.replace(" ", ".")

print(new_email_name)


#Split full_name using split() function

print(full_name.split())


# Join name parts using join() function if needed

split_user_name = ['Karunya', 'Jayaraman']
new_user_name = "." . join(split_user_name)
print(new_user_name)

# Create email in format: name@domain

email = new_user_name + "@" + domain_name

# Display output
print("\n----- Email Details -----")
print(f"Full Name       : {full_name}")
print(f"Generated Email : {email}")
# Out:
# Enter Full_name : Karunya Jayaraman
# Enter Domain_name : gmail.com
# karunya jayaraman
# Karunya.Jayaraman
# ['Karunya', 'Jayaraman']
# Karunya.Jayaraman
#
# ----- Email Details -----
# Full Name       : Karunya Jayaraman
# Generated Email : Karunya.Jayaraman@gmail.com
