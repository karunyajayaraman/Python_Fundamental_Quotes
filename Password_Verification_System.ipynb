# %% [markdown]
# <a href="https://colab.research.google.com/github/karunyajayaraman/Python_Fundamental_Quotes/blob/main/Password_Verification_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study – Password Verification System

# %%
# Original password
password = "python123"

# Taking input from user
user_password = input("Enter the password: ")

# while loop for password checking
while user_password != password:
    print("Incorrect password... try again")
    user_password = input("Enter the password: ")

else:
    print("Access granted")
# Out:
# Enter the password: jk123
# Incorrect password... try again
# Enter the password: kk1234
# Incorrect password... try again
# Enter the password: python123
# Access granted
