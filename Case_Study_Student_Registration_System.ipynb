# %% [markdown]
# <a href="https://colab.research.google.com/github/karunyajayaraman/Python_Fundamental_Quotes/blob/main/Case_Study_Student_Registration_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study – Student Registration System

# %% [markdown]
# # Create variables:

# %% [markdown]
# # student details

# %%
student_name = input("Enter student name : " )
student_age = int(input("Enter student age : "))
course_name = input("Enter course name : ")
course_fee = float(input("Enter course fee : "))
# Out:
# Enter student name : Nimalan
# Enter student age : 24
# Enter course name : Data Engineering
# Enter course fee : 65000

# %%
# Calculate-course_fee

gst = 0.18 * course_fee
total_fee = course_fee + gst

# %%
# gst - decimal point- Any number with a decimal point is treated as a float
# When an int and a float are used in an arithmetic operation, Python converts the result to a float automatically.

# %%
# Display data type

print(type(student_name))
print(type(student_age))
print(type(course_name))
print(type(course_fee))
print(type(gst))
print(type(total_fee))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# Display all student details using: print() function

# %% [markdown]
# #---------------STUDENT DETAILS-----------------

# %%
print(f"Enter student name : {student_name} \nEnter student age : {student_age} \nEnter Course name : {course_name} \nEnter course fee : {course_fee}")
print(f"\nGST : {gst} \nTotal Fee : {total_fee}")
# Out:
# Enter student name : Nimalan
# Enter student age : 24
# Enter Course name : Data Engineering
# Enter course fee : 65000.0
#
# GST : 11700.0
# Total Fee : 76700.0
