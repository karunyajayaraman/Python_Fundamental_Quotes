# %% [markdown]
# <a href="https://colab.research.google.com/github/karunyajayaraman/Python_Fundamental_Quotes/blob/main/Library_Fine_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case study - Library Fine Calculator

# %%
# Get input from user

student_name = input("Enter Student Name: ")
book_name = input("Enter Book Name: ")
days_late = int(input("Enter Number of Days Late: "))
fine_per_day = float(input("Enter Fine Per Day: "))
# Out:
# Enter Student Name: JK
# Enter Book Name: MATHS
# Enter Number of Days Late: 5
# Enter Fine Per Day: 10

# %%
# Calculate total fine
total_fine = days_late * fine_per_day

# %%
# Display details

print("\n----- Library Fine Details -----")
print(f"Student Name : {student_name}")
print(f"Book Name    : {book_name}")
print(f"Days Late    : {days_late}")
print(f"Fine Per Day : ₹{fine_per_day}")
print(f"Total Fine   : ₹{total_fine}")
# Out:
# ----- Library Fine Details -----
# Student Name : JK
# Book Name    : MATHS
# Days Late    : 5
# Fine Per Day : ₹10.0
# Total Fine   : ₹375.0

# %%
# Display datatypes

print("\n----- Datatypes -----")
print(f"student_name : {type(student_name)}")
print(f"book_name    : {type(book_name)}")
print(f"days_late    : {type(days_late)}")
print(f"fine_per_day : {type(fine_per_day)}")
print(f"total_fine   : {type(total_fine)}")
# Out:
# ----- Datatypes -----
# student_name : <class 'str'>
# book_name    : <class 'str'>
# days_late    : <class 'int'>
# fine_per_day : <class 'float'>
# total_fine   : <class 'float'>
