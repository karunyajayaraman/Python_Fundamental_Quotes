# %% [markdown]
# <a href="https://colab.research.google.com/github/karunyajayaraman/Python_Fundamental_Quotes/blob/main/Arithmetic_Calculator_using_User_Defined_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study – Arithmetic Calculator using User Defined Function
# Instructions
#
# Create a function called arth_cal()
#
# Pass two parameters to the function
#
# Inside the function:Perform addition, subtraction, multiplication
#
# Return all three values using multiple return statements
#
# Take two numbers from the user using input()
#
# Store returned values in separate variables
#
# Display:Sum, Difference, Multiplication

# %%
def calc(a,b):

  add = a + b
  sub = a - b
  mul = a * b
  div = a / b

  return add, sub, mul, div

# User Input
num1 = int(input("Enter First Number : "))
num2 = int(input("Enter Second Number : "))

# call the function

add,sub, mul, div = calc(num1, num2)

print(f"Addition : {add}")
print(f"Subtraction : {sub}")
print(f"Multiplication : {mul}")
print(f"Division : {div}")
# Out:
# Enter First Number : 50
# Enter Second Number : 48
# Addition : 98
# Subtraction : 2
# Multiplication : 2400
# Division : 1.0416666666666667
